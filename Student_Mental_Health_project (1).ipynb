# %%
import pandas as pd
data = pd.read_csv(r"D:\python\SMHP PROJECT\SMHP_Project\SMHP_DATA.csv")
data
# Out:
#            id  Gender  Age           City Profession  Academic Pressure  \
# 0           2    Male   33  Visakhapatnam    Student                  5
# 1           8  Female   24      Bangalore    Student                  2
# 2          30  Female   28       Varanasi    Student                  3
# 3          52    Male   30          Thane    Student                  3
# 4          56  Female   30        Chennai    Student                  2
# ...       ...     ...  ...            ...        ...                ...
# 12560  140669  Female   20         Indore    Student                  3
# 12561  140684    Male   31        Lucknow    Student                  2
# 12562  140685  Female   27          Surat    Student                  5
# 12563  140690  Female   18       Ludhiana    Student                  5
# 12564  140699    Male   27          Patna    Student                  4
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0                  0  8.97                   2                 0
# 1                  0  5.90                   5                 0
# 2                  0  5.59                   2                 0
# 3                  0  9.54                   4                 0
# 4                  0  8.04                   4                 0
# ...              ...   ...                 ...               ...
# 12560              0  7.72                   5                 0
# 12561              0  7.27                   5                 0
# 12562              0  5.75                   5                 0
# 12563              0  6.88                   2                 0
# 12564              0  9.24                   1                 0
#
#           Sleep Duration Dietary Habits    Degree  \
# 0              5-6 hours        Healthy   B.Pharm
# 1              5-6 hours       Moderate       BSc
# 2              7-8 hours       Moderate       BCA
# 3              7-8 hours        Healthy       BSc
# 4      Less than 5 hours      Unhealthy  Class 12
# ...                  ...            ...       ...
# 12560  Less than 5 hours       Moderate  Class 12
# 12561          7-8 hours       Moderate     B.Com
# 12562          5-6 hours      Unhealthy  Class 12
# 12563  Less than 5 hours        Healthy  Class 12
# 12564  Less than 5 hours        Healthy       BCA
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0                                       Yes                 3
# 1                                        No                 3
# 2                                       Yes                 4
# 3                                        No                 1
# 4                                        No                 0
# ...                                     ...               ...
# 12560                                   Yes                 8
# 12561                                   Yes                 6
# 12562                                   Yes                 7
# 12563                                   Yes                10
# 12564                                   Yes                 2
#
#        Financial Stress Family History of Mental Illness  Depression
# 0                   1.0                               No           1
# 1                   2.0                              Yes           0
# 2                   5.0                              Yes           1
# 3                   2.0                               No           0
# 4                   1.0                              Yes           0
# ...                 ...                              ...         ...
# 12560               1.0                               No           0
# 12561               1.0                              Yes           0
# 12562               1.0                              Yes           0
# 12563               5.0                               No           1
# 12564               3.0                              Yes           1
#
# [12565 rows x 18 columns]

# %% [markdown]
# ## DATA PREPROCESSING

# %%
data.isnull()
data['Financial Stress'] = data['Financial Stress'].fillna(data['Financial Stress'].mean())

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12565 entries, 0 to 12564
# Data columns (total 18 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     12565 non-null  int64
#  1   Gender                                 12565 non-null  object
#  2   Age                                    12565 non-null  int64
#  3   City                                   12565 non-null  object
#  4   Profession                             12565 non-null  object
#  5   Academic Pressure                      12565 non-null  int64
#  6   Work Pressure                          12565 non-null  int64
#  7   CGPA                                   12565 non-null  float64
#  8   Study Satisfaction                     12565 non-null  int64
#  9   Job Satisfaction                       12565 non-null  int64
#  10  Sleep Duration                         12565 non-null  object
#  11  Dietary Habits                         12565 non-null  object
#  12  Degree                                 12565 non-null  object
#  13  Have you ever had suicidal thoughts ?  12565 non-null  object
#  14  Work/Study Hours                       12565 non-null  int64
#  15  Financial Stress                       12565 non-null  float64
#  16  Family History of Mental Illness       12565 non-null  object
#  17  Depression                             12565 non-null  int64
# dtypes: float64(2), int64(8), object(8)
# memory usage: 1.7+ MB

# %%
data = data.drop(['id','Profession','Work Pressure','Job Satisfaction','City'],axis =1)
data
# Out:
#        Gender  Age  Academic Pressure  CGPA  Study Satisfaction  \
# 0        Male   33                  5  8.97                   2
# 1      Female   24                  2  5.90                   5
# 2      Female   28                  3  5.59                   2
# 3        Male   30                  3  9.54                   4
# 4      Female   30                  2  8.04                   4
# ...       ...  ...                ...   ...                 ...
# 12560  Female   20                  3  7.72                   5
# 12561    Male   31                  2  7.27                   5
# 12562  Female   27                  5  5.75                   5
# 12563  Female   18                  5  6.88                   2
# 12564    Male   27                  4  9.24                   1
#
#           Sleep Duration Dietary Habits    Degree  \
# 0              5-6 hours        Healthy   B.Pharm
# 1              5-6 hours       Moderate       BSc
# 2              7-8 hours       Moderate       BCA
# 3              7-8 hours        Healthy       BSc
# 4      Less than 5 hours      Unhealthy  Class 12
# ...                  ...            ...       ...
# 12560  Less than 5 hours       Moderate  Class 12
# 12561          7-8 hours       Moderate     B.Com
# 12562          5-6 hours      Unhealthy  Class 12
# 12563  Less than 5 hours        Healthy  Class 12
# 12564  Less than 5 hours        Healthy       BCA
#
#       Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0                                       Yes                 3
# 1                                        No                 3
# 2                                       Yes                 4
# 3                                        No                 1
# 4                                        No                 0
# ...                                     ...               ...
# 12560                                   Yes                 8
# 12561                                   Yes                 6
# 12562                                   Yes                 7
# 12563                                   Yes                10
# 12564                                   Yes                 2
#
#        Financial Stress Family History of Mental Illness  Depression
# 0                   1.0                               No           1
# 1                   2.0                              Yes           0
# 2                   5.0                              Yes           1
# 3                   2.0                               No           0
# 4                   1.0                              Yes           0
# ...                 ...                              ...         ...
# 12560               1.0                               No           0
# 12561               1.0                              Yes           0
# 12562               1.0                              Yes           0
# 12563               5.0                               No           1
# 12564               3.0                              Yes           1
#
# [12565 rows x 13 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
data['Gender'] = le.fit_transform(data['Gender'])
data['Sleep Duration'] = le.fit_transform(data['Sleep Duration'])
data['Dietary Habits'] = le.fit_transform(data['Dietary Habits'])
data['Degree']= le.fit_transform(data['Degree'])
data['Have you ever had suicidal thoughts ?'] = le.fit_transform(data['Have you ever had suicidal thoughts ?'])
data['Family History of Mental Illness'] = le.fit_transform(data['Family History of Mental Illness'])
data
# Out:
#        Gender  Age  Academic Pressure  CGPA  Study Satisfaction  \
# 0           1   33                  5  8.97                   2
# 1           0   24                  2  5.90                   5
# 2           0   28                  3  5.59                   2
# 3           1   30                  3  9.54                   4
# 4           0   30                  2  8.04                   4
# ...       ...  ...                ...   ...                 ...
# 12560       0   20                  3  7.72                   5
# 12561       1   31                  2  7.27                   5
# 12562       0   27                  5  5.75                   5
# 12563       0   18                  5  6.88                   2
# 12564       1   27                  4  9.24                   1
#
#        Sleep Duration  Dietary Habits  Degree  \
# 0                   0               0       1
# 1                   0               1       5
# 2                   1               1       4
# 3                   1               0       5
# 4                   2               3       6
# ...               ...             ...     ...
# 12560               2               1       6
# 12561               1               1       0
# 12562               0               3       6
# 12563               2               0       6
# 12564               2               0       4
#
#        Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0                                          1                 3
# 1                                          0                 3
# 2                                          1                 4
# 3                                          0                 1
# 4                                          0                 0
# ...                                      ...               ...
# 12560                                      1                 8
# 12561                                      1                 6
# 12562                                      1                 7
# 12563                                      1                10
# 12564                                      1                 2
#
#        Financial Stress  Family History of Mental Illness  Depression
# 0                   1.0                                 0           1
# 1                   2.0                                 1           0
# 2                   5.0                                 1           1
# 3                   2.0                                 0           0
# 4                   1.0                                 1           0
# ...                 ...                               ...         ...
# 12560               1.0                                 0           0
# 12561               1.0                                 1           0
# 12562               1.0                                 1           0
# 12563               5.0                                 0           1
# 12564               3.0                                 1           1
#
# [12565 rows x 13 columns]

# %%
x = data.drop(['Depression'],axis = 1)
x
# Out:
#        Gender  Age  Academic Pressure  CGPA  Study Satisfaction  \
# 0           1   33                  5  8.97                   2
# 1           0   24                  2  5.90                   5
# 2           0   28                  3  5.59                   2
# 3           1   30                  3  9.54                   4
# 4           0   30                  2  8.04                   4
# ...       ...  ...                ...   ...                 ...
# 12560       0   20                  3  7.72                   5
# 12561       1   31                  2  7.27                   5
# 12562       0   27                  5  5.75                   5
# 12563       0   18                  5  6.88                   2
# 12564       1   27                  4  9.24                   1
#
#        Sleep Duration  Dietary Habits  Degree  \
# 0                   0               0       1
# 1                   0               1       5
# 2                   1               1       4
# 3                   1               0       5
# 4                   2               3       6
# ...               ...             ...     ...
# 12560               2               1       6
# 12561               1               1       0
# 12562               0               3       6
# 12563               2               0       6
# 12564               2               0       4
#
#        Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0                                          1                 3
# 1                                          0                 3
# 2                                          1                 4
# 3                                          0                 1
# 4                                          0                 0
# ...                                      ...               ...
# 12560                                      1                 8
# 12561                                      1                 6
# 12562                                      1                 7
# 12563                                      1                10
# 12564                                      1                 2
#
#        Financial Stress  Family History of Mental Illness
# 0                   1.0                                 0
# 1                   2.0                                 1
# 2                   5.0                                 1
# 3                   2.0                                 0
# 4                   1.0                                 1
# ...                 ...                               ...
# 12560               1.0                                 0
# 12561               1.0                                 1
# 12562               1.0                                 1
# 12563               5.0                                 0
# 12564               3.0                                 1
#
# [12565 rows x 12 columns]

# %%
y = data['Depression']
y
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 12560    0
# 12561    0
# 12562    0
# 12563    1
# 12564    1
# Name: Depression, Length: 12565, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2)

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()
x_train, y_train = smote.fit_resample(x_train, y_train)

# %%
print(x_train)
# Out:
#        Gender  Age  Academic Pressure      CGPA  Study Satisfaction  \
# 0           1   25                  3  6.750000                   2
# 1           1   18                  4  5.350000                   4
# 2           1   27                  4  5.880000                   4
# 3           0   21                  4  6.160000                   3
# 4           0   19                  4  8.940000                   3
# ...       ...  ...                ...       ...                 ...
# 12727       1   18                  1  7.235071                   2
# 12728       1   26                  1  7.230240                   2
# 12729       0   34                  2  9.560852                   1
# 12730       0   24                  3  9.887695                   3
# 12731       0   22                  1  5.783723                   2
#
#        Sleep Duration  Dietary Habits  Degree  \
# 0                   3               3       3
# 1                   0               3       6
# 2                   2               3       5
# 3                   2               1       0
# 4                   1               3       6
# ...               ...             ...     ...
# 12727               2               0       6
# 12728               0               0       3
# 12729               0               1       5
# 12730               0               0       1
# 12731               2               1       0
#
#        Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 0                                          0                 5
# 1                                          1                 7
# 2                                          1                 4
# 3                                          1                 4
# 4                                          1                11
# ...                                      ...               ...
# 12727                                      0                12
# 12728                                      0                 2
# 12729                                      0                 6
# 12730                                      0                 0
# 12731                                      0                 2
#
#        Financial Stress  Family History of Mental Illness
# 0              2.000000                                 0
# 1              3.000000                                 1
# 2              3.000000                                 0
# 3              4.000000                                 0
# 4              3.000000                                 0
# ...                 ...                               ...
# 12727          1.000000                                 0
# 12728          4.809760                                 0
# 12729          4.255926                                 0
# 12730          1.000000                                 1
# 12731          4.000000                                 1
#
# [12732 rows x 12 columns]

# %%
print(x_test)
# Out:
#        Gender  Age  Academic Pressure  CGPA  Study Satisfaction  \
# 12024       0   20                  4  9.92                   3
# 2119        0   20                  5  6.25                   2
# 7126        1   29                  2  8.81                   2
# 4212        0   20                  4  5.84                   2
# 2978        1   28                  4  6.99                   2
# ...       ...  ...                ...   ...                 ...
# 5100        1   23                  3  7.09                   3
# 6994        1   20                  5  5.86                   1
# 4714        0   19                  5  8.95                   5
# 1433        0   32                  3  6.10                   5
# 3090        1   23                  1  8.52                   1
#
#        Sleep Duration  Dietary Habits  Degree  \
# 12024               0               1       6
# 2119                2               3       6
# 7126                0               0       0
# 4212                3               0       6
# 2978                2               3       0
# ...               ...             ...     ...
# 5100                1               3       2
# 6994                2               3       6
# 4714                3               1       6
# 1433                2               3       0
# 3090                0               3       5
#
#        Have you ever had suicidal thoughts ?  Work/Study Hours  \
# 12024                                      1                 2
# 2119                                       1                 3
# 7126                                       0                10
# 4212                                       1                 0
# 2978                                       1                11
# ...                                      ...               ...
# 5100                                       1                10
# 6994                                       1                12
# 4714                                       1                 4
# 1433                                       0                 6
# 3090                                       1                12
#
#        Financial Stress  Family History of Mental Illness
# 12024               4.0                                 0
# 2119                4.0                                 0
# 7126                5.0                                 0
# 4212                4.0                                 0
# 2978                5.0                                 0
# ...                 ...                               ...
# 5100                5.0                                 0
# 6994                5.0                                 1
# 4714                4.0                                 1
# 1433                4.0                                 0
# 3090                4.0                                 1
#
# [2513 rows x 12 columns]

# %%
print(y_train)
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 12727    0
# 12728    0
# 12729    0
# 12730    0
# 12731    0
# Name: Depression, Length: 12732, dtype: int64

# %%
print(y_test)
# Out:
# 12024    1
# 2119     1
# 7126     0
# 4212     1
# 2978     1
#         ..
# 5100     1
# 6994     1
# 4714     1
# 1433     0
# 3090     1
# Name: Depression, Length: 2513, dtype: int64

# %%
import xgboost as xgb
xgb_model = xgb.XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)
xgb_model.fit(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\SURYA MANOJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\formatters.py:977, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     974     method = get_real_method(obj, self.print_method)
#     976     if method is not None:
# --> 977         return method(include=include, exclude=exclude)
#     978     return None
#     979 else:
#
# File c:\Users\SURYA MANOJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:469, in BaseEstimator._repr_mimebundle_(self, **kwargs)
#     467 output = {"text/plain": repr(self)}
#     468 if get_config()["display"] == "diagram":
# --> 469     output["text/html"] = estimator_html_repr(self)
#     470 return output
#
# File c:\Users\SURYA MANOJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_estimator_html_repr.py:387, in estimator_html_repr(estimator)
#     385 else:
#     386     try:
# --> 387         check_is_fitted(estimator)
#     388         status_label = "<span>Fitted</span>"
#     389         is_fitted_css_class = "fitted"
#
# File c:\Users\SURYA MANOJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1751, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1748 if not hasattr(estimator, "fit"):
#    1749     raise TypeError("%s is not an estimator instance." % (estimator))
# -> 1751 tags = get_tags(estimator)
#    1753 if not tags.requires_fit and attributes is None:
#    1754     return
#
# File c:\Users\SURYA MANOJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_tags.py:430, in get_tags(estimator)
#     428 for klass in reversed(type(estimator).mro()):
#     429     if "__sklearn_tags__" in vars(klass):
# --> 430         sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     431         class_order.append(klass)
#     432     elif "_more_tags" in vars(klass):
#
# File c:\Users\SURYA MANOJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:540, in ClassifierMixin.__sklearn_tags__(self)
#     539 def __sklearn_tags__(self):
# --> 540     tags = super().__sklearn_tags__()
#     541     tags.estimator_type = "classifier"
#     542     tags.classifier_tags = ClassifierTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\SURYA MANOJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\IPython\core\formatters.py:347, in BaseFormatter.__call__(self, obj)
#     345     method = get_real_method(obj, self.print_method)
#     346     if method is not None:
# --> 347         return method()
#     348     return None
#     349 else:
#
# File c:\Users\SURYA MANOJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:463, in BaseEstimator._repr_html_inner(self)
#     458 def _repr_html_inner(self):
#     459     """This function is returned by the @property `_repr_html_` to make
#     460     `hasattr(estimator, "_repr_html_") return `True` or `False` depending
#     461     on `get_config()["display"]`.
#     462     """
# --> 463     return estimator_html_repr(self)
#
# File c:\Users\SURYA MANOJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_estimator_html_repr.py:387, in estimator_html_repr(estimator)
#     385 else:
#     386     try:
# --> 387         check_is_fitted(estimator)
#     388         status_label = "<span>Fitted</span>"
#     389         is_fitted_css_class = "fitted"
#
# File c:\Users\SURYA MANOJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1751, in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1748 if not hasattr(estimator, "fit"):
#    1749     raise TypeError("%s is not an estimator instance." % (estimator))
# -> 1751 tags = get_tags(estimator)
#    1753 if not tags.requires_fit and attributes is None:
#    1754     return
#
# File c:\Users\SURYA MANOJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\_tags.py:430, in get_tags(estimator)
#     428 for klass in reversed(type(estimator).mro()):
#     429     if "__sklearn_tags__" in vars(klass):
# --> 430         sklearn_tags_provider[klass] = klass.__sklearn_tags__(estimator)  # type: ignore[attr-defined]
#     431         class_order.append(klass)
#     432     elif "_more_tags" in vars(klass):
#
# File c:\Users\SURYA MANOJ\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:540, in ClassifierMixin.__sklearn_tags__(self)
#     539 def __sklearn_tags__(self):
# --> 540     tags = super().__sklearn_tags__()
#     541     tags.estimator_type = "classifier"
#     542     tags.classifier_tags = ClassifierTags()
#
# AttributeError: 'super' object has no attribute '__sklearn_tags__'
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
xgb_predictions = xgb_model.predict(x_test)
print(xgb_predictions)
# Out:
# [1 1 0 ... 1 0 1]

# %%
from sklearn.metrics import accuracy_score
xgbas = accuracy_score(y_test,xgb_predictions)
xgbas
# Out:
# 0.8531635495423796

# %%
import pickle
with open('xgb_model.pkl', 'wb') as file:
    pickle.dump(xgb_model, file)

# %%
with open('xgb_model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# %%
# Taking input from the user with corrected syntax and formatting
Gender = int(input("Enter the Gender \n 'Female': 0 \n 'Male': 1\n"))
Age = float(input("Enter the Age: "))
Academic_Pressure = float(input("Enter the Academic Pressure: "))
CGPA = float(input("Enter the CGPA: "))
Study_Satisfaction = float(input("Enter the Study Satisfaction: "))
Sleep_Duration = int(input("\nEnter the Sleep Duration\n '5-6 hours': 0 \n '7-8 hours': 1 \n 'Less than 5 hours': 2\n 'More than 8 hours' : 3"))
Dietary_Habits = int(input("\nEnter the Dietary Habits \n 'Healthy': 0 \n 'Moderate': 1 \n 'Unhealthy': 2\n"))
Degree = int(input("Enter Your Degree \n 'B.Pharm': 0 \n 'BA': 1 \n 'BCA': 2 \n 'BSc': 3 \n 'Class 12': 4 \n 'M.Tech': 5 \n 'MD': 6 \n 'MSc': 7\n"))
Suicidal_Thoughts = int(input("Enter if you have ever had suicidal thoughts \n 'No': 0 \n 'Yes': 1\n"))
Work_Study_Hours = float(input("Enter Work/Study Hours: "))
Financial_Stress = float(input("Enter the Financial Stress: "))
Family_History_Mental_Illness = int(input("Enter Family History of Mental Illness \n 'No': 0 \n 'Yes': 1\n"))

# Displaying the collected data
print("\nCollected Data:")
print(f"Gender: {Gender}")
print(f"Age: {Age}")
print(f"Academic Pressure: {Academic_Pressure}")
print(f"CGPA: {CGPA}")
print(f"Study Satisfaction: {Study_Satisfaction}")
print(f"Sleep Duration: {Sleep_Duration}")
print(f"Dietary Habits: {Dietary_Habits}")
print(f"Degree: {Degree}")
print(f"Suicidal Thoughts: {Suicidal_Thoughts}")
print(f"Work/Study Hours: {Work_Study_Hours}")
print(f"Financial Stress: {Financial_Stress}")
print(f"Family History of Mental Illness: {Family_History_Mental_Illness}")

'''
  539	Female	24	Kolkata	Student	5	0	8.96	1	0	5-6 hours	Moderate	BCA	Yes	12	5	No	1
'''

# %%
import numpy as np
input_data = np.array([[
    Gender,
    Age,
    Academic_Pressure,
    CGPA,
    Study_Satisfaction,
    Sleep_Duration,
    Dietary_Habits,
    Degree,
    Suicidal_Thoughts,
    Work_Study_Hours,
    Financial_Stress,
    Family_History_Mental_Illness
]])

# Make a prediction
prediction = clf_model.predict(input_data)
prediction_prob = clf_model.predict_proba(input_data)

# Display the results
print("\nPrediction Result:")
if prediction[0] == 1:
    print("The model predicts: The Students Mental Health is not good")
else:
    print("The model predicts: The Students Mental Health is  good")

print("\nPrediction Probability:")
print(f"Probability of Having Good Mental Health : {prediction_prob[0][0]:.2f}")
print(f"Probability of Not Having the Good Mental Health: {prediction_prob[0][1]:.2f}")
